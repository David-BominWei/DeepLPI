# %%
from DeepPurpose.dataset import load_process_DAVIS

load_process_DAVIS(path = './data', binary = False, convert_to_log = True, threshold = 30)
# Out:
# Beginning Processing...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /home/wbm001/miniconda3/envs/DeepPurpose/lib/python3.6/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1348                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1349                           encode_chunked=req.has_header('Transfer-encoding'))
#    1350             except OSError as err: # timeout error
#
# /home/wbm001/miniconda3/envs/DeepPurpose/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1286         """Send a complete request to the server."""
# -> 1287         self._send_request(method, url, body, headers, encode_chunked)
#    1288
#
# /home/wbm001/miniconda3/envs/DeepPurpose/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
# ...
